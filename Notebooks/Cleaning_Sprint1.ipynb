# %% [markdown]
# <center>
#     <h1> Toronto Crime </h1>
# <h3> Sprint 1</h3>
# <h3> Data Cleaning</h3>
#     </center>

# %% [markdown]
# ##### Author: Arsalan Arif Radhu
# ##### Date: 11 October 2023

# %% [markdown]
# ### Table of Contents:
# - [Introduction](#intro) <br />
# - [Basic Cleaning](#part1) <br />

# %% [markdown]
# ### Introduction <a id="intro" />

# %% [markdown]
# This notebook aims to merge multiple datasets into one for cleaning and analysis.

# %% [markdown]
# Importing all the required libraries.

# %%
import numpy as np  #importing numpy library
import pandas as pd #importing pandas library

# %% [markdown]
# ### Basic Cleaning <a id="part1" />

# %% [markdown]
# We will first import the new dataset and do some basic EDA to get a grasp of how it is after the processing.

# %% [markdown]
# Importing our data and reading through it.

# %%
#Reading the csv file
assualt_df = pd.read_csv('../Data/Assualt.csv',low_memory=False, index_col=0)
autoTheft_df = pd.read_csv('../Data/Auto Theft.csv',low_memory=False, index_col=0)
bicycleTheft_df = pd.read_csv('../Data/Bicycle Theft.csv',low_memory=False, index_col=0)
homicide_df = pd.read_csv('../Data/Homicide.csv',low_memory=False, index_col=0)
motorTheft_df = pd.read_csv('../Data/Motor Theft.csv',low_memory=False, index_col=0)
robbery_df = pd.read_csv('../Data/Robbery.csv',low_memory=False, index_col=0)
shootings_df = pd.read_csv('../Data/Shootings.csv',low_memory=False, index_col=0)
theftOver_df = pd.read_csv('../Data/Theft Over.csv',low_memory=False, index_col=0)

final=[assualt_df,autoTheft_df,bicycleTheft_df,homicide_df,motorTheft_df,robbery_df,shootings_df,theftOver_df] 

"""
Go through all th data files, and fix the columns expecially dates.regfgf
fgsdf
wwww
subin

"""
#HEllo World.;

final_df=pd.concat(final)

# %%
final_df.sample(100)
# Out:
#          CRIME_TYPE EVENT_UNIQUE_ID REPORT_DATE_FIXED   REPORT_DATE  \
# OBJECTID
# 4401          Theft  GO-20159004133        2015-07-03  1.440000e+12
# 28050         Theft   GO-2017559332        2017-03-30  1.490000e+12
# 13657         Theft  GO-20179018299        2017-10-27  1.510000e+12
# 128887      Assualt  GO-20201948429        2020-10-14  1.600000e+12
# 171773      Assualt  GO-20222390969        2022-12-07  1.670000e+12
# ...             ...             ...               ...           ...
# 20278       Robbery   GO-2019914712        2019-05-19  1.560000e+12
# 161989      Assualt  GO-20221258537        2022-07-02  1.660000e+12
# 48513       Assualt  GO-20161661880        2016-09-18  1.470000e+12
# 21783         Theft  GO-20191485098        2019-08-06  1.570000e+12
# 65425       Assualt  GO-20171436234        2017-08-09  1.500000e+12
#
#          OCC_DATE_FIXED      OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  \
# OBJECTID
# 4401         2015-07-03  1.440000e+12       2015.0         July         3.0
# 28050        2017-03-27  1.490000e+12       2017.0        March        30.0
# 13657        2017-10-26  1.510000e+12       2017.0      October        27.0
# 128887       2020-10-13  1.600000e+12       2020.0      October        14.0
# 171773       2022-12-07  1.670000e+12       2022.0     December         7.0
# ...                 ...           ...          ...          ...         ...
# 20278        2019-05-19  1.560000e+12       2019.0          May        19.0
# 161989       2022-07-01  1.660000e+12       2022.0         July         2.0
# 48513        2016-09-18  1.470000e+12       2016.0    September        18.0
# 21783        2018-12-21  1.550000e+12       2019.0       August         6.0
# 65425        2017-08-05  1.500000e+12       2017.0       August         9.0
#
#           REPORT_DOY  ... BIKE_TYPE  BIKE_SPEED  BIKE_COLOUR BIKE_COST  \
# OBJECTID              ...
# 4401           184.0  ...        OT         1.0          BLU    800.00
# 28050           89.0  ...       NaN         NaN          NaN       NaN
# 13657          300.0  ...        MT        20.0          ONG   1354.87
# 128887         288.0  ...       NaN         NaN          NaN       NaN
# 171773         341.0  ...       NaN         NaN          NaN       NaN
# ...              ...  ...       ...         ...          ...       ...
# 20278          139.0  ...       NaN         NaN          NaN       NaN
# 161989         183.0  ...       NaN         NaN          NaN       NaN
# 48513          262.0  ...       NaN         NaN          NaN       NaN
# 21783          218.0  ...       NaN         NaN          NaN       NaN
# 65425          221.0  ...       NaN         NaN          NaN       NaN
#
#           STATUS  HOMICIDE_TYPE F_num_removed  OCC_TIME_RANGE DEATH INJURIES
# OBJECTID
# 4401      STOLEN            NaN           NaN             NaN   NaN      NaN
# 28050        NaN            NaN           NaN             NaN   NaN      NaN
# 13657     STOLEN            NaN           NaN             NaN   NaN      NaN
# 128887       NaN            NaN           NaN             NaN   NaN      NaN
# 171773       NaN            NaN           NaN             NaN   NaN      NaN
# ...          ...            ...           ...             ...   ...      ...
# 20278        NaN            NaN           NaN             NaN   NaN      NaN
# 161989       NaN            NaN           NaN             NaN   NaN      NaN
# 48513        NaN            NaN           NaN             NaN   NaN      NaN
# 21783        NaN            NaN           NaN             NaN   NaN      NaN
# 65425        NaN            NaN           NaN             NaN   NaN      NaN
#
# [100 rows x 44 columns]

# %% [markdown]
# The data looks to have concatenated well and the number of columns have risen to <b>43!</b> So, I will be dropping some columns which contained either useless data, redundant data or data which is not necessary for my analysis.

# %%
# Doesn't make sense
final_df.drop('F_num_removed', axis=1, inplace=True)
final_df.drop('OCC_TIME_RANGE', axis=1, inplace=True)

# Old redundant data 
final_df.drop('NEIGHBOURHOOD_140', axis=1, inplace=True)
final_df.drop('HOOD_140', axis=1, inplace=True)
final_df.drop('REPORT_DATE', axis=1, inplace=True)
final_df.drop('OCC_DATE', axis=1, inplace=True)

# Resetting index since it got mixed up while concatanating 
final_df.reset_index(drop=True)

# Are not going to be used in my analysis
final_df.drop('BIKE_MAKE', axis=1, inplace=True)
final_df.drop('BIKE_MODEL', axis=1, inplace=True)
final_df.drop('BIKE_TYPE', axis=1, inplace=True)
final_df.drop('BIKE_SPEED', axis=1, inplace=True)
final_df.drop('BIKE_COLOUR', axis=1, inplace=True)
final_df.drop('BIKE_COST', axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381419 entries, 1 to 10745
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CRIME_TYPE         381419 non-null  object
#  1   EVENT_UNIQUE_ID    381419 non-null  object
#  2   REPORT_DATE_FIXED  374390 non-null  object
#  3   OCC_DATE_FIXED     381419 non-null  object
#  4   REPORT_YEAR        374390 non-null  float64
#  5   REPORT_MONTH       374390 non-null  object
#  6   REPORT_DAY         374390 non-null  float64
#  7   REPORT_DOY         374390 non-null  float64
#  8   REPORT_DOW         374390 non-null  object
#  9   REPORT_HOUR        374390 non-null  float64
#  10  OCC_YEAR           381298 non-null  float64
#  11  OCC_MONTH          381298 non-null  object
#  12  OCC_DAY            381298 non-null  float64
#  13  OCC_DOY            381298 non-null  float64
#  14  OCC_DOW            381298 non-null  object
#  15  OCC_HOUR           380097 non-null  float64
#  16  DIVISION           381419 non-null  object
#  17  LOCATION_TYPE      374390 non-null  object
#  18  PREMISES_TYPE      374390 non-null  object
#  19  UCR_CODE           342420 non-null  float64
#  20  UCR_EXT            342420 non-null  float64
#  21  OFFENCE            342420 non-null  object
#  22  MCI_CATEGORY       342420 non-null  object
#  23  HOOD_158           381419 non-null  object
#  24  NEIGHBOURHOOD_158  381419 non-null  object
#  25  LONG_WGS84         381419 non-null  float64
#  26  LAT_WGS84          381419 non-null  float64
#  27  PRIMARY_OFFENCE    31970 non-null   object
#  28  STATUS             31970 non-null   object
#  29  HOMICIDE_TYPE      1322 non-null    object
#  30  DEATH              5707 non-null    float64
#  31  INJURIES           5707 non-null    float64
# dtypes: float64(14), object(18)
# memory usage: 96.0+ MB

# %% [markdown]
# As we can see, after dropping all the unnecessary columns we are left with <b>31</b> columns. We can also observe that there seems to be a lot of `NULL` values. So, let's check for them!

# %%
final_df.isna().sum()
# Out:
# CRIME_TYPE                0
# EVENT_UNIQUE_ID           0
# REPORT_DATE_FIXED      7029
# OCC_DATE_FIXED            0
# REPORT_YEAR            7029
# REPORT_MONTH           7029
# REPORT_DAY             7029
# REPORT_DOY             7029
# REPORT_DOW             7029
# REPORT_HOUR            7029
# OCC_YEAR                121
# OCC_MONTH               121
# OCC_DAY                 121
# OCC_DOY                 121
# OCC_DOW                 121
# OCC_HOUR               1322
# DIVISION                  0
# LOCATION_TYPE          7029
# PREMISES_TYPE          7029
# UCR_CODE              38999
# UCR_EXT               38999
# OFFENCE               38999
# MCI_CATEGORY          38999
# HOOD_158                  0
# NEIGHBOURHOOD_158         0
# LONG_WGS84                0
# LAT_WGS84                 0
# PRIMARY_OFFENCE      349449
# STATUS               349449
# HOMICIDE_TYPE        380097
# DEATH                375712
# INJURIES             375712
# dtype: int64

# %% [markdown]
# As we can see there are a lot of `NULL` values. After doing some research I realized the `DEATH` and `INJURIES` columns were specific for `Shooting` dataset, and hence the huge amounts of `NULL` values. So, to fix that I will be filling the `NULL` values in these two columns with `0` as this will indicate that no-one was injured or killed in any other types of crimes. The `HOMICIDE_TYPE` column is also specific to the `Homicide` dataset hence I will be filling the `NULL` values with "N/A". Similarly, `STATUS` and `PRIMARY_OFFENCE` is specific to the `Bike_Theft` data set, so I will be filling the `NULL` values wiht "N/A". The reason I am not dropping these columns is that even though they are specific to one type of crime, they provide very valuable insight into that crime, so for now I don't have any strong reasons to drop them.
# `OFFENCE`,`UCR_EXIT`and `UCR_CODE` columns have exact same number of `NULL`, which implies that all of them might come from the same data set and after further investigation that was the case. They were `NULL` due to them not being present in the `Bike Theft` data set, since they're not a required category for them we can fill these with `N/A` as well.
# `REPORT_DATE_FIXED` has so many `NULL` values as `Homicide` and `Shootings` did not have any report dates or information. I am assuming that is the case as `Homicide` and `Shootings` both are severe crimes which usually don't have a difference in Occurence and reporting times. So we can fill some of the `NULL` values with the `OCC_DATE_FIXED`.

# %%
# Filling the NULL values
final_df["DEATH"] = final_df["DEATH"].fillna(0)
final_df["INJURIES"] = final_df["INJURIES"].fillna(0)
final_df["HOMICIDE_TYPE"] = final_df["HOMICIDE_TYPE"].fillna("NotApplicable")
final_df["STATUS"] = final_df["STATUS"].fillna("NotApplicable")
final_df["PRIMARY_OFFENCE"] = final_df["PRIMARY_OFFENCE"].fillna("NotApplicable")
final_df["MCI_CATEGORY"] = final_df["MCI_CATEGORY"].fillna("NonMCI")
final_df["OFFENCE"] = final_df["OFFENCE"].fillna("NotApplicable")
final_df["UCR_EXT"] = final_df["UCR_EXT"].fillna("NotApplicable")
final_df["UCR_CODE"] = final_df["UCR_CODE"].fillna("NotApplicable")
final_df["LOCATION_TYPE"] = final_df["LOCATION_TYPE"].fillna("NotApplicable")
final_df["PREMISES_TYPE"] = final_df["PREMISES_TYPE"].fillna("NotApplicable")
final_df["REPORT_DATE_FIXED"] = final_df["REPORT_DATE_FIXED"].fillna(final_df["OCC_DATE_FIXED"])

#air_traffic_clean.fillna(method="ffill",inplace=True)

# %%
final_df.isna().sum()
# Out:
# CRIME_TYPE              0
# EVENT_UNIQUE_ID         0
# REPORT_DATE_FIXED       0
# OCC_DATE_FIXED          0
# REPORT_YEAR          7029
# REPORT_MONTH         7029
# REPORT_DAY           7029
# REPORT_DOY           7029
# REPORT_DOW           7029
# REPORT_HOUR          7029
# OCC_YEAR              121
# OCC_MONTH             121
# OCC_DAY               121
# OCC_DOY               121
# OCC_DOW               121
# OCC_HOUR             1322
# DIVISION                0
# LOCATION_TYPE           0
# PREMISES_TYPE           0
# UCR_CODE                0
# UCR_EXT                 0
# OFFENCE                 0
# MCI_CATEGORY            0
# HOOD_158                0
# NEIGHBOURHOOD_158       0
# LONG_WGS84              0
# LAT_WGS84               0
# PRIMARY_OFFENCE         0
# STATUS                  0
# HOMICIDE_TYPE           0
# DEATH                   0
# INJURIES                0
# dtype: int64

# %% [markdown]
# After filling majority of `NULL` values we are still left with some, I could not really find a good way of substituiting them so I will be dropping them. This should not affect the analysis much because of the huge number of data I have.

# %% [markdown]
# Now checking for duplicates in the data.

# %%
final_df.duplicated().sum()
# Out:
# 29515

# %% [markdown]
# As we can see we have around `~30,000` duplicates! Let's check whether they are actually duplicates or not.

# %%
final_df.loc[final_df.duplicated(), :].sort_values("EVENT_UNIQUE_ID")
# Out:
#          CRIME_TYPE EVENT_UNIQUE_ID REPORT_DATE_FIXED OCC_DATE_FIXED  \
# OBJECTID
# 55         Homicide   GO-2004734705        2004-12-01     2004-12-01
# 108        Homicide  GO-20051068304        2005-08-07     2005-08-07
# 125        Homicide  GO-20051156513        2005-09-16     2005-09-16
# 124        Homicide  GO-20051156513        2005-09-16     2005-09-16
# 131        Homicide  GO-20051265274        2005-10-23     2005-10-23
# ...             ...             ...               ...            ...
# 40006         Theft   GO-2022995203        2022-05-27     2022-05-22
# 40001         Theft   GO-2022995776        2022-05-27     2022-05-26
# 9807          Theft   GO-2022995987        2022-05-27     2022-05-24
# 40003         Theft   GO-2022997755        2022-05-27     2022-05-26
# 159668      Assualt   GO-2022999907        2022-05-27     2022-05-27
#
#           REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  \
# OBJECTID
# 55                NaN          NaN         NaN         NaN         NaN
# 108               NaN          NaN         NaN         NaN         NaN
# 125               NaN          NaN         NaN         NaN         NaN
# 124               NaN          NaN         NaN         NaN         NaN
# 131               NaN          NaN         NaN         NaN         NaN
# ...               ...          ...         ...         ...         ...
# 40006          2022.0          May        27.0       147.0  Friday
# 40001          2022.0          May        27.0       147.0  Friday
# 9807           2022.0          May        27.0       147.0  Friday
# 40003          2022.0          May        27.0       147.0  Friday
# 159668         2022.0          May        27.0       147.0  Friday
#
#           REPORT_HOUR  ...  MCI_CATEGORY HOOD_158  \
# OBJECTID               ...
# 55                NaN  ...        NonMCI      172
# 108               NaN  ...        NonMCI       71
# 125               NaN  ...        NonMCI        5
# 124               NaN  ...        NonMCI        5
# 131               NaN  ...        NonMCI        2
# ...               ...  ...           ...      ...
# 40006             7.0  ...    Auto Theft       23
# 40001             8.0  ...    Auto Theft      108
# 9807             15.0  ...    Theft Over      159
# 40003            13.0  ...    Auto Theft      108
# 159668           19.0  ...       Assault       70
#
#                           NEIGHBOURHOOD_158  LONG_WGS84  LAT_WGS84  \
# OBJECTID
# 55                       Dovercourt Village  -79.428717  43.669298
# 108         Cabbagetown-South St.James Town  -79.375516  43.665735
# 125                        Elms-Old Rexdale  -79.549360  43.727283
# 124                        Elms-Old Rexdale  -79.549360  43.727283
# 131       Mount Olive-Silverstone-Jamestown  -79.591700  43.736767
# ...                                     ...         ...        ...
# 40006                  Pelmo Park-Humberlea  -79.537287  43.717017
# 40001                  Briar Hill-Belgravia  -79.449333  43.695892
# 9807                  Etobicoke City Centre  -79.527286  43.634209
# 40003                  Briar Hill-Belgravia  -79.449333  43.695892
# 159668                      South Riverdale  -79.328487  43.659320
#
#           PRIMARY_OFFENCE         STATUS  HOMICIDE_TYPE DEATH INJURIES
# OBJECTID
# 55          NotApplicable  NotApplicable       Stabbing   0.0      0.0
# 108         NotApplicable  NotApplicable       Shooting   0.0      0.0
# 125         NotApplicable  NotApplicable       Shooting   0.0      0.0
# 124         NotApplicable  NotApplicable       Shooting   0.0      0.0
# 131         NotApplicable  NotApplicable       Shooting   0.0      0.0
# ...                   ...            ...            ...   ...      ...
# 40006       NotApplicable  NotApplicable  NotApplicable   0.0      0.0
# 40001       NotApplicable  NotApplicable  NotApplicable   0.0      0.0
# 9807        NotApplicable  NotApplicable  NotApplicable   0.0      0.0
# 40003       NotApplicable  NotApplicable  NotApplicable   0.0      0.0
# 159668      NotApplicable  NotApplicable  NotApplicable   0.0      0.0
#
# [29515 rows x 32 columns]

# %% [markdown]
# There seems to be some real duplicates! So we can drop the duplicates!

# %%
final_df= final_df.drop_duplicates()

# %% [markdown]
# After dropping, we have no more duplicates left as confirmed below!

# %%
final_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Just a final check before we can export this final 'clean' copy of the data set.

# %%
final_df.sample(1000)
# Out:
#          CRIME_TYPE EVENT_UNIQUE_ID REPORT_DATE_FIXED OCC_DATE_FIXED  \
# OBJECTID
# 11807       Assualt  GO-20142929564        2014-09-17     2014-09-17
# 6770        Robbery  GO-20151926847        2015-11-09     2015-11-09
# 16956       Robbery  GO-20181131892        2018-06-21     2018-06-21
# 26478         Theft  GO-20219011203        2021-05-11     2021-05-10
# 71232         Theft  GO-20212229251        2021-11-19     2021-11-19
# ...             ...             ...               ...            ...
# 91467       Assualt  GO-20182200834        2018-11-30     2018-11-30
# 172494      Assualt  GO-20222478575        2022-12-19     2022-12-19
# 116267      Assualt   GO-2020285080        2020-02-10     2020-02-08
# 148016      Assualt  GO-20212029088        2021-10-21     2021-10-21
# 95529       Assualt   GO-2019324286        2019-02-20     2018-04-01
#
#           REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  \
# OBJECTID
# 11807          2014.0    September        17.0       260.0  Wednesday
# 6770           2015.0     November         9.0       313.0  Monday
# 16956          2018.0         June        21.0       172.0  Thursday
# 26478          2021.0          May        11.0       131.0     Tuesday
# 71232          2021.0     November        19.0       323.0  Friday
# ...               ...          ...         ...         ...         ...
# 91467          2018.0     November        30.0       334.0  Friday
# 172494         2022.0     December        19.0       353.0  Monday
# 116267         2020.0     February        10.0        41.0  Monday
# 148016         2021.0      October        21.0       294.0  Thursday
# 95529          2019.0     February        20.0        51.0  Wednesday
#
#           REPORT_HOUR  ...  MCI_CATEGORY HOOD_158    NEIGHBOURHOOD_158  \
# OBJECTID               ...
# 11807            17.0  ...       Assault      107      Oakwood Village
# 6770             16.0  ...       Robbery      156  Bendale-Glen Andrew
# 16956            22.0  ...       Robbery      172   Dovercourt Village
# 26478            20.0  ...        NonMCI       94             Wychwood
# 71232            10.0  ...        NonMCI       95                Annex
# ...               ...  ...           ...      ...                  ...
# 91467            10.0  ...       Assault      167     Church-Wellesley
# 172494           16.0  ...       Assault       42    Banbury-Don Mills
# 116267            1.0  ...       Assault      NSA                  NSA
# 148016           23.0  ...       Assault      139  Scarborough Village
# 95529            17.0  ...       Assault       62    East End-Danforth
#
#           LONG_WGS84  LAT_WGS84  PRIMARY_OFFENCE         STATUS  \
# OBJECTID
# 11807     -79.440841  43.692648    NotApplicable  NotApplicable
# 6770      -79.258520  43.752852    NotApplicable  NotApplicable
# 16956     -79.420245  43.663165    NotApplicable  NotApplicable
# 26478     -79.416755  43.679242      THEFT UNDER         STOLEN
# 71232     -79.406270  43.666159    NotApplicable  NotApplicable
# ...              ...        ...              ...            ...
# 91467     -79.383945  43.665060    NotApplicable  NotApplicable
# 172494    -79.342709  43.734428    NotApplicable  NotApplicable
# 116267    -85.488744   0.000000    NotApplicable  NotApplicable
# 148016    -79.217033  43.738771    NotApplicable  NotApplicable
# 95529     -79.298848  43.680736    NotApplicable  NotApplicable
#
#           HOMICIDE_TYPE DEATH INJURIES
# OBJECTID
# 11807     NotApplicable   0.0      0.0
# 6770      NotApplicable   0.0      0.0
# 16956     NotApplicable   0.0      0.0
# 26478     NotApplicable   0.0      0.0
# 71232     NotApplicable   0.0      0.0
# ...                 ...   ...      ...
# 91467     NotApplicable   0.0      0.0
# 172494    NotApplicable   0.0      0.0
# 116267    NotApplicable   0.0      0.0
# 148016    NotApplicable   0.0      0.0
# 95529     NotApplicable   0.0      0.0
#
# [1000 rows x 32 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 351904 entries, 1 to 10745
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CRIME_TYPE         351904 non-null  object
#  1   EVENT_UNIQUE_ID    351904 non-null  object
#  2   REPORT_DATE_FIXED  351904 non-null  object
#  3   OCC_DATE_FIXED     351904 non-null  object
#  4   REPORT_YEAR        344952 non-null  float64
#  5   REPORT_MONTH       344952 non-null  object
#  6   REPORT_DAY         344952 non-null  float64
#  7   REPORT_DOY         344952 non-null  float64
#  8   REPORT_DOW         344952 non-null  object
#  9   REPORT_HOUR        344952 non-null  float64
#  10  OCC_YEAR           351791 non-null  float64
#  11  OCC_MONTH          351791 non-null  object
#  12  OCC_DAY            351791 non-null  float64
#  13  OCC_DOY            351791 non-null  float64
#  14  OCC_DOW            351791 non-null  object
#  15  OCC_HOUR           350659 non-null  float64
#  16  DIVISION           351904 non-null  object
#  17  LOCATION_TYPE      351904 non-null  object
#  18  PREMISES_TYPE      351904 non-null  object
#  19  UCR_CODE           351904 non-null  object
#  20  UCR_EXT            351904 non-null  object
#  21  OFFENCE            351904 non-null  object
#  22  MCI_CATEGORY       351904 non-null  object
#  23  HOOD_158           351904 non-null  object
#  24  NEIGHBOURHOOD_158  351904 non-null  object
#  25  LONG_WGS84         351904 non-null  float64
#  26  LAT_WGS84          351904 non-null  float64
#  27  PRIMARY_OFFENCE    351904 non-null  object
#  28  STATUS             351904 non-null  object
#  29  HOMICIDE_TYPE      351904 non-null  object
#  30  DEATH              351904 non-null  float64
#  31  INJURIES           351904 non-null  float64
# dtypes: float64(12), object(20)
# memory usage: 88.6+ MB

# %% [markdown]
# Other thing I noticed was that all the columns related to year, death, injuries and day etc. are of float data type which doesn't make sense as any of these cannot have decimal places. So I will change the data type to int.

# %%
final_df[['REPORT_DAY','REPORT_YEAR','REPORT_DOY','REPORT_HOUR','OCC_YEAR','OCC_DAY','OCC_DOY','OCC_HOUR','DEATH','INJURIES']]=final_df[['REPORT_DAY','REPORT_YEAR','REPORT_DOY','REPORT_HOUR','OCC_YEAR','OCC_DAY','OCC_DOY','OCC_HOUR','DEATH','INJURIES']].astype('Int64')

# %% [markdown]
# Final check!

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 351904 entries, 1 to 10745
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CRIME_TYPE         351904 non-null  object
#  1   EVENT_UNIQUE_ID    351904 non-null  object
#  2   REPORT_DATE_FIXED  351904 non-null  object
#  3   OCC_DATE_FIXED     351904 non-null  object
#  4   REPORT_YEAR        344952 non-null  Int64
#  5   REPORT_MONTH       344952 non-null  object
#  6   REPORT_DAY         344952 non-null  Int64
#  7   REPORT_DOY         344952 non-null  Int64
#  8   REPORT_DOW         344952 non-null  object
#  9   REPORT_HOUR        344952 non-null  Int64
#  10  OCC_YEAR           351791 non-null  Int64
#  11  OCC_MONTH          351791 non-null  object
#  12  OCC_DAY            351791 non-null  Int64
#  13  OCC_DOY            351791 non-null  Int64
#  14  OCC_DOW            351791 non-null  object
#  15  OCC_HOUR           350659 non-null  Int64
#  16  DIVISION           351904 non-null  object
#  17  LOCATION_TYPE      351904 non-null  object
#  18  PREMISES_TYPE      351904 non-null  object
#  19  UCR_CODE           351904 non-null  object
#  20  UCR_EXT            351904 non-null  object
#  21  OFFENCE            351904 non-null  object
#  22  MCI_CATEGORY       351904 non-null  object
#  23  HOOD_158           351904 non-null  object
#  24  NEIGHBOURHOOD_158  351904 non-null  object
#  25  LONG_WGS84         351904 non-null  float64
#  26  LAT_WGS84          351904 non-null  float64
#  27  PRIMARY_OFFENCE    351904 non-null  object
#  28  STATUS             351904 non-null  object
#  29  HOMICIDE_TYPE      351904 non-null  object
#  30  DEATH              351904 non-null  Int64
#  31  INJURIES           351904 non-null  Int64
# dtypes: Int64(10), float64(2), object(20)
# memory usage: 92.0+ MB

# %% [markdown]
# It looks good! I think we can export it into a new file, and we can start our basic EDA.

# %%
final_df.to_csv('../Data/FinalData.csv')
