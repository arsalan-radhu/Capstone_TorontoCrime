# %% [markdown]
# <center>
#     <h1> Toronto Crime </h1>
# <h3> Sprint 1</h3>
# <h3> Data Cleaning</h3>
#     </center>

# %% [markdown]
# ##### Author: Arsalan Arif Radhu
# ##### Date: 11 October 2023

# %% [markdown]
# ### Table of Contents:
# - [Introduction](#intro) <br />
# - [Part 1 - Basic Analysis](#part1) <br />
#     - [1.1](#1.1) <br />
#     - [1.2](#1.2) <br />
# - [Part 2 - Statistical Analysis](#part2) <br />
#     - [2.1](#2.1) <br />
#     - [2.2](#2.2) <br />
# - [Part 3 - Advanced Statistical Analysis](#part3)<br />
#     - [3.1](#3.1) <br />
#     - [3.2](#3.2) <br />
# - [Summary](#summary)

# %% [markdown]
# ### Introduction <a id="intro" />

# %% [markdown]
# This notebook aims to merge multiple datasets into one for cleaning and analysis.

# %% [markdown]
# Importing all the required libraries.

# %%
import numpy as np  #importing numpy library
import pandas as pd #importing pandas library
import matplotlib.pyplot as plt #importing matplotlib library
import seaborn as sns #importing seaborn library 
import statsmodels.api as sm #importing statsmodel library 
from scipy import stats #importing scientific py library 
import datetime

# %% [markdown]
# ### Part 1 - Basic Analysis <a id="part1" />

# %% [markdown]
# We will first import the new dataset and do some basic EDA to get a grasp of how it is after the processing.

# %% [markdown]
# Importing our data and reading through it.

# %%
#Reading the csv file
assualt_df = pd.read_csv('../Data/Assualt.csv',low_memory=False, index_col=0)
autoTheft_df = pd.read_csv('../Data/Auto Theft.csv',low_memory=False, index_col=0)
bicycleTheft_df = pd.read_csv('../Data/Bicycle Theft.csv',low_memory=False, index_col=0)
homicide_df = pd.read_csv('../Data/Homicide.csv',low_memory=False, index_col=0)
motorTheft_df = pd.read_csv('../Data/Motor Theft.csv',low_memory=False, index_col=0)
robbery_df = pd.read_csv('../Data/Robbery.csv',low_memory=False, index_col=0)
shootings_df = pd.read_csv('../Data/Shootings.csv',low_memory=False, index_col=0)
theftOver_df = pd.read_csv('../Data/Theft Over.csv',low_memory=False, index_col=0)

final=[assualt_df,autoTheft_df,bicycleTheft_df,homicide_df,motorTheft_df,robbery_df,shootings_df,theftOver_df] 

"""
Go through all th data files, and fix the columns expecially dates.regfgf
fgsdf
wwww
subin

"""
#HEllo World.;

final_df=pd.concat(final)
# Out:
#          EVENT_UNIQUE_ID REPORT_DATE_FIXED   REPORT_DATE OCC_DATE_FIXED  \
# OBJECTID
# 140033    GO-20211051351        2021-06-06  1.622950e+12     2021-06-06
# 4839      GO-20201853895               NaN           NaN     2020-09-29
# 6243      GO-20142161928        2014-05-27  1.401160e+12     2014-05-27
# 5617      GO-20142076245        2014-05-14  1.400040e+12     2014-05-13
# 62429     GO-20209027658        2020-10-25  1.603600e+12     2020-10-24
# ...                  ...               ...           ...            ...
# 130100    GO-20202117543        2020-11-08  1.604810e+12     2020-11-07
# 32231     GO-20151918011        2015-11-08  1.446960e+12     2015-11-08
# 14009     GO-20179021127        2017-12-03  1.510000e+12     2017-12-01
# 134081     GO-2021239776        2021-02-07  1.612670e+12     2021-02-07
# 8491      GO-20161164586        2016-07-03  1.467520e+12     2016-06-25
#
#                  OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  \
# OBJECTID
# 140033    1622950000000.0       2021.0         June         6.0       157.0
# 4839      1600000000000.0          NaN          NaN         NaN         NaN
# 6243      1401160000000.0       2014.0          May        27.0       147.0
# 5617      1399950000000.0       2014.0          May        14.0       134.0
# 62429     1603510000000.0       2020.0      October        25.0       299.0
# ...                   ...          ...          ...         ...         ...
# 130100    1604730000000.0       2020.0     November         8.0       313.0
# 32231     1446960000000.0       2015.0     November         8.0       312.0
# 14009     1510000000000.0       2017.0     December         3.0       337.0
# 134081    1612670000000.0       2021.0     February         7.0        38.0
# 8491      1466830000000.0       2016.0         July         3.0       185.0
#
#           REPORT_DOW  ...  BIKE_TYPE  BIKE_SPEED BIKE_COLOUR  BIKE_COST  \
# OBJECTID              ...
# 140033    Sunday      ...        NaN         NaN         NaN        NaN
# 4839             NaN  ...        NaN         NaN         NaN        NaN
# 6243      Tuesday     ...        NaN         NaN         NaN        NaN
# 5617      Wednesday   ...        NaN         NaN         NaN        NaN
# 62429     Sunday      ...        NaN         NaN         NaN        NaN
# ...              ...  ...        ...         ...         ...        ...
# 130100    Sunday      ...        NaN         NaN         NaN        NaN
# 32231     Sunday      ...        NaN         NaN         NaN        NaN
# 14009         Sunday  ...         MT         5.0         NaN      250.0
# 134081    Sunday      ...        NaN         NaN         NaN        NaN
# 8491      Sunday      ...        NaN         NaN         NaN        NaN
#
#           STATUS HOMICIDE_TYPE  F_num_removed OCC_TIME_RANGE DEATH INJURIES
# OBJECTID
# 140033       NaN           NaN            NaN            NaN   NaN      NaN
# 4839         NaN           NaN            NaN        Evening   0.0      0.0
# 6243         NaN           NaN            NaN            NaN   NaN      NaN
# 5617         NaN           NaN            NaN            NaN   NaN      NaN
# 62429        NaN           NaN            NaN            NaN   NaN      NaN
# ...          ...           ...            ...            ...   ...      ...
# 130100       NaN           NaN            NaN            NaN   NaN      NaN
# 32231        NaN           NaN            NaN            NaN   NaN      NaN
# 14009     STOLEN           NaN            NaN            NaN   NaN      NaN
# 134081       NaN           NaN            NaN            NaN   NaN      NaN
# 8491         NaN           NaN            NaN            NaN   NaN      NaN
#
# [100 rows x 43 columns]

# %%
final_df["OFFENCE"].sample(100)
# Out:
# OBJECTID
# 29522                 Assault
# 11430      Robbery - Swarming
# 141684    Assault With Weapon
# 85823                 Assault
# 25169                 Assault
#                  ...
# 140161    Assault With Weapon
# 141798    Assault With Weapon
# 9351                  Assault
# 717           Robbery - Other
# 151881                Assault
# Name: OFFENCE, Length: 100, dtype: object

# %% [markdown]
# The data looks to have concatenated well and the number of columns have risen to <b>43!</b> So, I will be dropping some columns which contained either useless data, redundant data or data which is not necessary for mmy analysis.

# %%
# Doesn't make sense
final_df.drop('F_num_removed', axis=1, inplace=True)
final_df.drop('OCC_TIME_RANGE', axis=1, inplace=True)

# Old redundant data 
final_df.drop('NEIGHBOURHOOD_140', axis=1, inplace=True)
final_df.drop('HOOD_140', axis=1, inplace=True)
final_df.drop('REPORT_DATE', axis=1, inplace=True)
final_df.drop('OCC_DATE', axis=1, inplace=True)

# Resetting index since it got mixed up while concatanating 
final_df.reset_index(drop=True)

# Are not going to be used in my analysis
final_df.drop('BIKE_MAKE', axis=1, inplace=True)
final_df.drop('BIKE_MODEL', axis=1, inplace=True)
final_df.drop('BIKE_TYPE', axis=1, inplace=True)
final_df.drop('BIKE_SPEED', axis=1, inplace=True)
final_df.drop('BIKE_COLOUR', axis=1, inplace=True)
final_df.drop('BIKE_COST', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Brainstation\Capstone_TorontoCrime\Notebooks\Sprint1.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/d%3A/Brainstation/Capstone_TorontoCrime/Notebooks/Sprint1.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Doesn't make sense
# ----> <a href='vscode-notebook-cell:/d%3A/Brainstation/Capstone_TorontoCrime/Notebooks/Sprint1.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> final_df.drop('F_num_removed', axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/d%3A/Brainstation/Capstone_TorontoCrime/Notebooks/Sprint1.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> final_df.drop('OCC_TIME_RANGE', axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/d%3A/Brainstation/Capstone_TorontoCrime/Notebooks/Sprint1.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> # Old redundant data
#
# File c:\Users\arifh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Users\arifh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\arifh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\arifh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['F_num_removed'] not found in axis"

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381419 entries, 1 to 10745
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EVENT_UNIQUE_ID    381419 non-null  object
#  1   REPORT_DATE_FIXED  374390 non-null  object
#  2   OCC_DATE_FIXED     380097 non-null  object
#  3   REPORT_YEAR        374390 non-null  float64
#  4   REPORT_MONTH       374390 non-null  object
#  5   REPORT_DAY         374390 non-null  float64
#  6   REPORT_DOY         374390 non-null  float64
#  7   REPORT_DOW         374390 non-null  object
#  8   REPORT_HOUR        374390 non-null  float64
#  9   OCC_YEAR           381298 non-null  float64
#  10  OCC_MONTH          381298 non-null  object
#  11  OCC_DAY            381298 non-null  float64
#  12  OCC_DOY            381298 non-null  float64
#  13  OCC_DOW            381298 non-null  object
#  14  OCC_HOUR           380097 non-null  float64
#  15  DIVISION           381419 non-null  object
#  16  LOCATION_TYPE      374390 non-null  object
#  17  PREMISES_TYPE      374390 non-null  object
#  18  UCR_CODE           342420 non-null  float64
#  19  UCR_EXT            342420 non-null  float64
#  20  OFFENCE            342420 non-null  object
#  21  MCI_CATEGORY       342420 non-null  object
#  22  HOOD_158           381419 non-null  object
#  23  NEIGHBOURHOOD_158  381419 non-null  object
#  24  LONG_WGS84         381419 non-null  float64
#  25  LAT_WGS84          381419 non-null  float64
#  26  PRIMARY_OFFENCE    31970 non-null   object
#  27  STATUS             31970 non-null   object
#  28  HOMICIDE_TYPE      1322 non-null    object
#  29  OCC_TIME_RANGE     5707 non-null    object
#  30  DEATH              5707 non-null    float64
#  31  INJURIES           5707 non-null    float64
# dtypes: float64(14), object(18)
# memory usage: 96.0+ MB

# %% [markdown]
# As we can see, after dropping all the unnecessary columns we are left with <b>31</b> columns. We can also observe that there seems to be a lot of `NULL` values. So, let's check for them!

# %%
final_df.isna().sum()
# Out:
# EVENT_UNIQUE_ID           0
# REPORT_DATE_FIXED      7029
# OCC_DATE_FIXED         1322
# REPORT_YEAR            7029
# REPORT_MONTH           7029
# REPORT_DAY             7029
# REPORT_DOY             7029
# REPORT_DOW             7029
# REPORT_HOUR            7029
# OCC_YEAR                121
# OCC_MONTH               121
# OCC_DAY                 121
# OCC_DOY                 121
# OCC_DOW                 121
# OCC_HOUR               1322
# DIVISION                  0
# LOCATION_TYPE          7029
# PREMISES_TYPE          7029
# UCR_CODE              38999
# UCR_EXT               38999
# OFFENCE               38999
# MCI_CATEGORY          38999
# HOOD_158                  0
# NEIGHBOURHOOD_158         0
# LONG_WGS84                0
# LAT_WGS84                 0
# PRIMARY_OFFENCE      349449
# STATUS               349449
# HOMICIDE_TYPE        380097
# OCC_TIME_RANGE       375712
# DEATH                375712
# INJURIES             375712
# dtype: int64

# %% [markdown]
# As we can see there are a lot of `NULL` values. After doing some research I realized the `DEATH` and `INJURIES` columns were specific for `Shooting` dataset, and hence the huge amounts of `NULL` values. So, to fix that I will be filling the `NULL` values in these two columns with `0` as this will indicate that no-one was injured or killed in any other types of crimes. The `HOMICIDE_TYPE` column is also specific to the `Homicide` dataset hence I will be filling the `NULL` values with "N/A". Similarly, `STATUS` and `PRIMARY_OFFENCE` is specific to the `Bike_Theft` data set, so I will be filling the `NULL` values wiht "N/A". The reason I am not dropping these columns is that even though they are specific to one type of crime, they provide very valuable insight into that crime, so for now I don't have any strong reasons to drop them.

# %%
# Filling the NULL values
final_df["DEATH"] = final_df["DEATH"].fillna(0)
final_df["INJURIES"] = final_df["INJURIES"].fillna(0)
final_df["HOMICIDE_TYPE"] = final_df["HOMICIDE_TYPE"].fillna("N/A")
final_df["STATUS"] = final_df["STATUS"].fillna("N/A")
final_df["PRIMARY_OFFENCE"] = final_df["PRIMARY_OFFENCE"].fillna("N/A")
final_df["MCI_CATEGORY"] = final_df["MCI_CATEGORY"].fillna("NonMCI")

# %%
final_df.isna().sum()
# Out:
# EVENT_UNIQUE_ID           0
# REPORT_DATE_FIXED      7029
# OCC_DATE_FIXED         1322
# REPORT_YEAR            7029
# REPORT_MONTH           7029
# REPORT_DAY             7029
# REPORT_DOY             7029
# REPORT_DOW             7029
# REPORT_HOUR            7029
# OCC_YEAR                121
# OCC_MONTH               121
# OCC_DAY                 121
# OCC_DOY                 121
# OCC_DOW                 121
# OCC_HOUR               1322
# DIVISION                  0
# LOCATION_TYPE          7029
# PREMISES_TYPE          7029
# UCR_CODE              38999
# UCR_EXT               38999
# OFFENCE               38999
# MCI_CATEGORY              0
# HOOD_158                  0
# NEIGHBOURHOOD_158         0
# LONG_WGS84                0
# LAT_WGS84                 0
# PRIMARY_OFFENCE           0
# STATUS                    0
# HOMICIDE_TYPE             0
# OCC_TIME_RANGE       375712
# DEATH                     0
# INJURIES                  0
# dtype: int64

# %%
final_df.duplicated().sum()
# Out:
# 29516

# %%
final_df.loc[final_df.duplicated(), :].sort_values("EVENT_UNIQUE_ID")
# Out:
#          EVENT_UNIQUE_ID REPORT_DATE_FIXED OCC_DATE_FIXED  REPORT_YEAR  \
# OBJECTID
# 7          GO-2004152518               NaN            NaN          NaN
# 55         GO-2004734705               NaN            NaN          NaN
# 108       GO-20051068304               NaN            NaN          NaN
# 125       GO-20051156513               NaN            NaN          NaN
# 124       GO-20051156513               NaN            NaN          NaN
# ...                  ...               ...            ...          ...
# 40006      GO-2022995203        2022-05-27     2022-05-22       2022.0
# 40001      GO-2022995776        2022-05-27     2022-05-26       2022.0
# 9807       GO-2022995987        2022-05-27     2022-05-24       2022.0
# 40003      GO-2022997755        2022-05-27     2022-05-26       2022.0
# 159668     GO-2022999907        2022-05-27     2022-05-27       2022.0
#
#          REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  \
# OBJECTID
# 7                 NaN         NaN         NaN         NaN          NaN
# 55                NaN         NaN         NaN         NaN          NaN
# 108               NaN         NaN         NaN         NaN          NaN
# 125               NaN         NaN         NaN         NaN          NaN
# 124               NaN         NaN         NaN         NaN          NaN
# ...               ...         ...         ...         ...          ...
# 40006             May        27.0       147.0  Friday              7.0
# 40001             May        27.0       147.0  Friday              8.0
# 9807              May        27.0       147.0  Friday             15.0
# 40003             May        27.0       147.0  Friday             13.0
# 159668            May        27.0       147.0  Friday             19.0
#
#           OCC_YEAR  ... HOOD_158                NEIGHBOURHOOD_158  LONG_WGS84  \
# OBJECTID            ...
# 7           2004.0  ...      154         Oakdale-Beverley Heights  -79.508631
# 55          2004.0  ...      172               Dovercourt Village  -79.428717
# 108         2005.0  ...       71  Cabbagetown-South St.James Town  -79.375516
# 125         2005.0  ...        5                 Elms-Old Rexdale  -79.549360
# 124         2005.0  ...        5                 Elms-Old Rexdale  -79.549360
# ...            ...  ...      ...                              ...         ...
# 40006       2022.0  ...       23             Pelmo Park-Humberlea  -79.537287
# 40001       2022.0  ...      108             Briar Hill-Belgravia  -79.449333
# 9807        2022.0  ...      159            Etobicoke City Centre  -79.527286
# 40003       2022.0  ...      108             Briar Hill-Belgravia  -79.449333
# 159668      2022.0  ...       70                  South Riverdale  -79.328487
#
#           LAT_WGS84  PRIMARY_OFFENCE STATUS HOMICIDE_TYPE OCC_TIME_RANGE  \
# OBJECTID
# 7         43.720909              N/A    N/A      Stabbing            NaN
# 55        43.669298              N/A    N/A      Stabbing            NaN
# 108       43.665735              N/A    N/A      Shooting            NaN
# 125       43.727283              N/A    N/A      Shooting            NaN
# 124       43.727283              N/A    N/A      Shooting            NaN
# ...             ...              ...    ...           ...            ...
# 40006     43.717017              N/A    N/A           N/A            NaN
# 40001     43.695892              N/A    N/A           N/A            NaN
# 9807      43.634209              N/A    N/A           N/A            NaN
# 40003     43.695892              N/A    N/A           N/A            NaN
# 159668    43.659320              N/A    N/A           N/A            NaN
#
#           DEATH  INJURIES
# OBJECTID
# 7           0.0       0.0
# 55          0.0       0.0
# 108         0.0       0.0
# 125         0.0       0.0
# 124         0.0       0.0
# ...         ...       ...
# 40006       0.0       0.0
# 40001       0.0       0.0
# 9807        0.0       0.0
# 40003       0.0       0.0
# 159668      0.0       0.0
#
# [29516 rows x 32 columns]

# %%
final_df= final_df.drop_duplicates()

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
final_df.isna().sum()
# Out:
# EVENT_UNIQUE_ID           0
# REPORT_DATE_FIXED      6951
# OCC_DATE_FIXED         1244
# REPORT_YEAR            6951
# REPORT_MONTH           6951
# REPORT_DAY             6951
# REPORT_DOY             6951
# REPORT_DOW             6951
# REPORT_HOUR            6951
# OCC_YEAR                113
# OCC_MONTH               113
# OCC_DAY                 113
# OCC_DOY                 113
# OCC_DOW                 113
# OCC_HOUR               1244
# DIVISION                  0
# LOCATION_TYPE          6951
# PREMISES_TYPE          6951
# UCR_CODE              35498
# UCR_EXT               35498
# OFFENCE               35498
# MCI_CATEGORY              0
# HOOD_158                  0
# NEIGHBOURHOOD_158         0
# LONG_WGS84                0
# LAT_WGS84                 0
# PRIMARY_OFFENCE           0
# STATUS                    0
# HOMICIDE_TYPE             0
# OCC_TIME_RANGE       346196
# DEATH                     0
# INJURIES                  0
# dtype: int64

# %%
final_df= final_df.drop_()

# %%
final_df.isna().sum()/final_df.shape[0]*100

# %%
pd.options.display.max_columns = 1000
final_df.head()

# %%
final_df.to_csv('FinalData.csv')
