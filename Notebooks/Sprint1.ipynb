# %% [markdown]
# <center>
#     <h1> Toronto Crime </h1>
# <h3> Sprint 1</h3>
#     </center>

# %% [markdown]
# ##### Author: Arsalan Arif Radhu
# ##### Date: 11 October 2023

# %% [markdown]
# ### Table of Contents:
# - [Introduction](#intro) <br />
# - [Part 1 - Basic Analysis](#part1) <br />
#     - [1.1](#1.1) <br />
#     - [1.2](#1.2) <br />
# - [Part 2 - Statistical Analysis](#part2) <br />
#     - [2.1](#2.1) <br />
#     - [2.2](#2.2) <br />
# - [Part 3 - Advanced Statistical Analysis](#part3)<br />
#     - [3.1](#3.1) <br />
#     - [3.2](#3.2) <br />
# - [Summary](#summary)

# %% [markdown]
# ### Introduction <a id="intro" />

# %% [markdown]
# This notebook aims to conduct advanced statistical analysis on the cleaned mosquito dataset. We will be trying to find the relationships between different variables and their effect on the mosquito number using different models. We will also be looking at the statistical significance between each variable as well.

# %% [markdown]
# Importing all the required libraries.

# %%
import numpy as np  #importing numpy library
import pandas as pd #importing pandas library
import matplotlib.pyplot as plt #importing matplotlib library
import seaborn as sns #importing seaborn library 
import statsmodels.api as sm #importing statsmodel library 
from scipy import stats #importing scientific py library 
import datetime

# %% [markdown]
# ### Part 1 - Basic Analysis <a id="part1" />

# %% [markdown]
# We will first import the new dataset and do some basic EDA to get a grasp of how it is after the processing.

# %% [markdown]
# Importing our data and reading through it.

# %%
#Reading the csv file
assualt_df = pd.read_csv('../Data/Assualt.csv',low_memory=False, index_col=0)
autoTheft_df = pd.read_csv('../Data/Auto Theft.csv',low_memory=False, index_col=0)
bicycleTheft_df = pd.read_csv('../Data/Bicycle Theft.csv',low_memory=False, index_col=0)
homicide_df = pd.read_csv('../Data/Homicide.csv',low_memory=False, index_col=0)
motorTheft_df = pd.read_csv('../Data/Motor Theft.csv',low_memory=False, index_col=0)
robbery_df = pd.read_csv('../Data/Robbery.csv',low_memory=False, index_col=0)
shootings_df = pd.read_csv('../Data/Shootings.csv',low_memory=False, index_col=0)
theftOver_df = pd.read_csv('../Data/Theft Over.csv',low_memory=False, index_col=0)

final=[assualt_df,autoTheft_df,bicycleTheft_df,homicide_df,motorTheft_df,robbery_df,shootings_df,theftOver_df] 

"""
Go through all th data files, and fix the columns expecially dates.regfgf
fgsdf
wwww
subin

"""
#HEllo World.;

#final_df=pd.concat(final)

#final_df.sample(100)
# Out:
#          EVENT_UNIQUE_ID   REPORT_DATE         OCC_DATE  REPORT_YEAR  \
# OBJECTID
# 56377      GO-2017339439  1.487826e+12    1487826000000       2017.0
# 21750      GO-2015655125  1.429502e+12    1429502400000       2015.0
# 25841     GO-20169014253  1.480914e+12    1480654800000       2016.0
# 49384     GO-20199025231  1.565150e+12    1565150400000       2019.0
# 784       GO-20072002015           NaN    1183780800000          NaN
# ...                  ...           ...              ...          ...
# 26992     GO-20219015145  1.624160e+12  1624160000000.0       2021.0
# 6453      GO-20151940601  1.447218e+12    1447218000000       2015.0
# 4263       GO-2015491690  1.427170e+12    1427083200000       2015.0
# 4757       GO-2015837515  1.432094e+12    1432008000000       2015.0
# 75243     GO-20229015007  1.651032e+12    1651032000000       2022.0
#
#          REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  \
# OBJECTID
# 56377        February        23.0        54.0  Thursday           15.0
# 21750           April        20.0       110.0  Monday             18.0
# 25841        December         5.0       340.0  Monday             16.0
# 49384          August         7.0       219.0  Wednesday          15.0
# 784               NaN         NaN         NaN         NaN          NaN
# ...               ...         ...         ...         ...          ...
# 26992            June        20.0       171.0      Sunday         18.0
# 6453         November        11.0       315.0  Wednesday          21.0
# 4263            March        24.0        83.0  Tuesday             9.0
# 4757              May        20.0       140.0  Wednesday           0.0
# 75243           April        27.0       117.0  Wednesday          22.0
#
#           OCC_YEAR  ... BIKE_TYPE  BIKE_SPEED  BIKE_COLOUR BIKE_COST  STATUS  \
# OBJECTID            ...
# 56377       2017.0  ...       NaN         NaN          NaN       NaN     NaN
# 21750       2015.0  ...       NaN         NaN          NaN       NaN     NaN
# 25841       2016.0  ...       NaN         NaN          NaN       NaN     NaN
# 49384       2019.0  ...       NaN         NaN          NaN       NaN     NaN
# 784         2007.0  ...       NaN         NaN          NaN       NaN     NaN
# ...            ...  ...       ...         ...          ...       ...     ...
# 26992       2021.0  ...        OT        10.0          BLK     300.0  STOLEN
# 6453        2015.0  ...       NaN         NaN          NaN       NaN     NaN
# 4263        2015.0  ...       NaN         NaN          NaN       NaN     NaN
# 4757        2015.0  ...       NaN         NaN          NaN       NaN     NaN
# 75243       2022.0  ...       NaN         NaN          NaN       NaN     NaN
#
#          HOMICIDE_TYPE F_num_removed OCC_TIME_RANGE  DEATH  INJURIES
# OBJECTID
# 56377              NaN           NaN            NaN    NaN       NaN
# 21750              NaN           NaN            NaN    NaN       NaN
# 25841              NaN           NaN            NaN    NaN       NaN
# 49384              NaN           NaN            NaN    NaN       NaN
# 784                NaN           NaN      Afternoon    0.0       1.0
# ...                ...           ...            ...    ...       ...
# 26992              NaN           NaN            NaN    NaN       NaN
# 6453               NaN           NaN            NaN    NaN       NaN
# 4263               NaN           NaN            NaN    NaN       NaN
# 4757               NaN           NaN            NaN    NaN       NaN
# 75243              NaN           NaN            NaN    NaN       NaN
#
# [100 rows x 41 columns]

# %%
assualt_df.sample(10)
# Out:
#          EVENT_UNIQUE_ID    REPORT_DATE       OCC_DATE  REPORT_YEAR  \
# OBJECTID
# 30470     GO-20151719881  1444017600000  1444017600000         2015
# 80141      GO-2018878452  1526356800000  1526270400000         2018
# 143073    GO-20211422546  1627444800000  1627444800000         2021
# 92681     GO-20182349926  1545541200000  1488344400000         2018
# 16559     GO-20143545516  1419397200000  1419397200000         2014
# 136125     GO-2021520406  1616299200000  1616299200000         2021
# 28951     GO-20151531664  1441425600000  1441425600000         2015
# 132584      GO-202113190  1609650000000  1609650000000         2021
# 77450      GO-2018551099  1522123200000  1521432000000         2018
# 66956     GO-20171621353  1504756800000  1504324800000         2017
#
#          REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  \
# OBJECTID
# 30470         October           5         278  Monday               17
# 80141             May          15         135  Tuesday              19
# 143073           July          28         209  Wednesday            19
# 92681        December          23         357  Sunday               21
# 16559        December          24         358  Wednesday            22
# 136125          March          21          80  Sunday               16
# 28951       September           5         248  Saturday              7
# 132584        January           3           3  Sunday               11
# 77450           March          27          86  Tuesday              10
# 66956       September           7         250  Thursday             14
#
#           OCC_YEAR  ... UCR_CODE  UCR_EXT                      OFFENCE  \
# OBJECTID            ...
# 30470       2015.0  ...     1430      100                      Assault
# 80141       2018.0  ...     1430      100                      Assault
# 143073      2021.0  ...     1420      100          Assault With Weapon
# 92681       2017.0  ...     1420      100          Assault With Weapon
# 16559       2014.0  ...     1430      100                      Assault
# 136125      2021.0  ...     1480      110  Administering Noxious Thing
# 28951       2015.0  ...     1430      100                      Assault
# 132584      2021.0  ...     1420      110          Assault Bodily Harm
# 77450       2018.0  ...     1430      100                      Assault
# 66956       2017.0  ...     1430      100                      Assault
#
#          MCI_CATEGORY  HOOD_158                      NEIGHBOURHOOD_158  \
# OBJECTID
# 30470         Assault        31                     Yorkdale-Glen Park
# 80141         Assault        46                          Pleasant View
# 143073        Assault        86                           Roncesvalles
# 92681         Assault        35                    Westminster-Branson
# 16559         Assault       168                    Downtown Yonge East
# 136125        Assault        95                                  Annex
# 28951         Assault       110               Keelesdale-Eglinton West
# 132584        Assault       121                               Oakridge
# 77450         Assault        61                          Taylor-Massey
# 66956         Assault       166  St Lawrence-East Bayfront-The Islands
#
#          HOOD_140                       NEIGHBOURHOOD_140  LONG_WGS84  \
# OBJECTID
# 30470          31                 Yorkdale-Glen Park (31)  -79.456169
# 80141          46                      Pleasant View (46)  -79.331409
# 143073         86                       Roncesvalles (86)  -79.450686
# 92681          35                Westminster-Branson (35)  -79.442529
# 16559          75              Church-Yonge Corridor (75)  -79.377145
# 136125         95                              Annex (95)  -79.397911
# 28951         110          Keelesdale-Eglinton West (110)  -79.475322
# 132584        121                          Oakridge (121)  -79.279513
# 77450          61                      Taylor-Massey (61)  -79.302112
# 66956          77  Waterfront Communities-The Island (77)  -79.377909
#
#           LAT_WGS84
# OBJECTID
# 30470     43.720456
# 80141     43.793100
# 143073    43.654267
# 92681     43.771990
# 16559     43.656495
# 136125    43.669227
# 28951     43.688116
# 132584    43.703213
# 77450     43.691992
# 66956     43.643211
#
# [10 rows x 28 columns]

# %%
assualt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173238 entries, 1 to 173238
# Data columns (total 28 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EVENT_UNIQUE_ID    173238 non-null  object
#  1   REPORT_DATE        173238 non-null  int64
#  2   OCC_DATE           173238 non-null  int64
#  3   REPORT_YEAR        173238 non-null  int64
#  4   REPORT_MONTH       173238 non-null  object
#  5   REPORT_DAY         173238 non-null  int64
#  6   REPORT_DOY         173238 non-null  int64
#  7   REPORT_DOW         173238 non-null  object
#  8   REPORT_HOUR        173238 non-null  int64
#  9   OCC_YEAR           173144 non-null  float64
#  10  OCC_MONTH          173144 non-null  object
#  11  OCC_DAY            173144 non-null  float64
#  12  OCC_DOY            173144 non-null  float64
#  13  OCC_DOW            173144 non-null  object
#  14  OCC_HOUR           173238 non-null  int64
#  15  DIVISION           173238 non-null  object
#  16  LOCATION_TYPE      173238 non-null  object
#  17  PREMISES_TYPE      173238 non-null  object
#  18  UCR_CODE           173238 non-null  int64
#  19  UCR_EXT            173238 non-null  int64
#  20  OFFENCE            173238 non-null  object
#  21  MCI_CATEGORY       173238 non-null  object
#  22  HOOD_158           173238 non-null  object
#  23  NEIGHBOURHOOD_158  173238 non-null  object
#  24  HOOD_140           173238 non-null  object
#  25  NEIGHBOURHOOD_140  173238 non-null  object
#  26  LONG_WGS84         173238 non-null  float64
#  27  LAT_WGS84          173238 non-null  float64
# dtypes: float64(5), int64(9), object(14)
# memory usage: 38.3+ MB

# %%
assualt_df[]
dt = datetime.datetime.fromtimestamp(0)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381419 entries, 1 to 10745
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EVENT_UNIQUE_ID    381419 non-null  object
#  1   REPORT_DATE        374390 non-null  float64
#  2   OCC_DATE           381419 non-null  object
#  3   REPORT_YEAR        374390 non-null  float64
#  4   REPORT_MONTH       374390 non-null  object
#  5   REPORT_DAY         374390 non-null  float64
#  6   REPORT_DOY         374390 non-null  float64
#  7   REPORT_DOW         374390 non-null  object
#  8   REPORT_HOUR        374390 non-null  float64
#  9   OCC_YEAR           381298 non-null  float64
#  10  OCC_MONTH          381298 non-null  object
#  11  OCC_DAY            381298 non-null  float64
#  12  OCC_DOY            381298 non-null  float64
#  13  OCC_DOW            381298 non-null  object
#  14  OCC_HOUR           380097 non-null  float64
#  15  DIVISION           381419 non-null  object
#  16  LOCATION_TYPE      374390 non-null  object
#  17  PREMISES_TYPE      374390 non-null  object
#  18  UCR_CODE           342420 non-null  float64
#  19  UCR_EXT            342420 non-null  float64
#  20  OFFENCE            342420 non-null  object
#  21  MCI_CATEGORY       342420 non-null  object
#  22  HOOD_158           381419 non-null  object
#  23  NEIGHBOURHOOD_158  381419 non-null  object
#  24  HOOD_140           381419 non-null  object
#  25  NEIGHBOURHOOD_140  381419 non-null  object
#  26  LONG_WGS84         381419 non-null  float64
#  27  LAT_WGS84          381419 non-null  float64
#  28  PRIMARY_OFFENCE    31970 non-null   object
#  29  BIKE_MAKE          31813 non-null   object
#  30  BIKE_MODEL         19893 non-null   object
#  31  BIKE_TYPE          31970 non-null   object
#  32  BIKE_SPEED         31970 non-null   float64
#  33  BIKE_COLOUR        29305 non-null   object
#  34  BIKE_COST          29808 non-null   float64
#  35  STATUS             31970 non-null   object
#  36  HOMICIDE_TYPE      1322 non-null    object
#  37  F_num_removed      858 non-null     float64
#  38  OCC_TIME_RANGE     5707 non-null    object
#  39  DEATH              5707 non-null    float64
#  40  INJURIES           5707 non-null    float64
# dtypes: float64(18), object(23)
# memory usage: 122.2+ MB

# %%
final_df.describe()
# Out:
#         REPORT_DATE    REPORT_YEAR     REPORT_DAY     REPORT_DOY  \
# count  3.743900e+05  374390.000000  374390.000000  374390.000000
# mean   1.535963e+12    2018.158623      15.757250     188.341000
# std    8.179961e+10       2.575272       8.741483     101.711403
# min    1.388550e+12    2014.000000       1.000000       1.000000
# 25%    1.466654e+12    2016.000000       8.000000     104.000000
# 50%    1.538107e+12    2018.000000      16.000000     192.000000
# 75%    1.604898e+12    2020.000000      23.000000     274.000000
# max    1.672463e+12    2022.000000      31.000000     366.000000
#
#          REPORT_HOUR       OCC_YEAR        OCC_DAY        OCC_DOY  \
# count  374390.000000  381298.000000  381298.000000  381298.000000
# mean       13.080953    2018.034409      15.446942     187.650554
# std         6.168116       2.745329       8.875606     101.939791
# min         0.000000    2000.000000       1.000000       1.000000
# 25%         9.000000    2016.000000       8.000000     103.000000
# 50%        13.000000    2018.000000      15.000000     191.000000
# 75%        18.000000    2020.000000      23.000000     274.000000
# max        23.000000    2022.000000      31.000000     366.000000
#
#             OCC_HOUR       UCR_CODE        UCR_EXT     LONG_WGS84  \
# count  380097.000000  342420.000000  342420.000000  381419.000000
# mean       13.098633    1732.836032     149.229563     -79.477742
# std         7.245826     338.053985      51.452598       0.697137
# min         0.000000    1410.000000     100.000000     -85.488744
# 25%         8.000000    1430.000000     100.000000     -79.478954
# 50%        15.000000    1480.000000     110.000000     -79.397033
# 75%        19.000000    2135.000000     200.000000     -79.332379
# max        23.000000    2142.000000     230.000000     -78.551414
#
#            LAT_WGS84    BIKE_SPEED      BIKE_COST  F_num_removed        DEATH  \
# count  381419.000000  31970.000000   29808.000000          858.0  5707.000000
# mean       43.137053     14.079262     973.016019            1.0     0.122481
# std         4.948195     10.553628    1609.044655            0.0     0.349599
# min         0.000000      0.000000       0.000000            1.0     0.000000
# 25%        43.658511      6.000000     360.000000            1.0     0.000000
# 50%        43.695288     15.000000     650.000000            1.0     0.000000
# 75%        43.748374     21.000000    1080.000000            1.0     0.000000
# max        44.351392     99.000000  120000.000000            1.0     3.000000
#
#           INJURIES
# count  5707.000000
# mean      0.488172
# std       0.779148
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max      24.000000

# %%
final_df.shape
# Out:
# (381419, 41)

# %%
final_df.duplicated().sum()
# Out:
# 26417

# %%
final_df.loc[final_df.duplicated(), :].sort_values("EVENT_UNIQUE_ID")
# Out:
#          EVENT_UNIQUE_ID   REPORT_DATE       OCC_DATE  REPORT_YEAR  \
# OBJECTID
# 7          GO-2004152518           NaN     2004.02.20          NaN
# 55         GO-2004734705           NaN     2004.12.01          NaN
# 108       GO-20051068304           NaN     2005.08.07          NaN
# 124       GO-20051156513           NaN     2005.09.16          NaN
# 125       GO-20051156513           NaN     2005.09.16          NaN
# ...                  ...           ...            ...          ...
# 40006      GO-2022995203  1.653624e+12  1653192000000       2022.0
# 40001      GO-2022995776  1.653624e+12  1653537600000       2022.0
# 9807       GO-2022995987  1.653624e+12  1653364800000       2022.0
# 40003      GO-2022997755  1.653624e+12  1653537600000       2022.0
# 159668     GO-2022999907  1.653624e+12  1653624000000       2022.0
#
#          REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  \
# OBJECTID
# 7                 NaN         NaN         NaN         NaN          NaN
# 55                NaN         NaN         NaN         NaN          NaN
# 108               NaN         NaN         NaN         NaN          NaN
# 124               NaN         NaN         NaN         NaN          NaN
# 125               NaN         NaN         NaN         NaN          NaN
# ...               ...         ...         ...         ...          ...
# 40006             May        27.0       147.0  Friday              7.0
# 40001             May        27.0       147.0  Friday              8.0
# 9807              May        27.0       147.0  Friday             15.0
# 40003             May        27.0       147.0  Friday             13.0
# 159668            May        27.0       147.0  Friday             19.0
#
#           OCC_YEAR  ... BIKE_TYPE  BIKE_SPEED  BIKE_COLOUR BIKE_COST  STATUS  \
# OBJECTID            ...
# 7           2004.0  ...       NaN         NaN          NaN       NaN     NaN
# 55          2004.0  ...       NaN         NaN          NaN       NaN     NaN
# 108         2005.0  ...       NaN         NaN          NaN       NaN     NaN
# 124         2005.0  ...       NaN         NaN          NaN       NaN     NaN
# 125         2005.0  ...       NaN         NaN          NaN       NaN     NaN
# ...            ...  ...       ...         ...          ...       ...     ...
# 40006       2022.0  ...       NaN         NaN          NaN       NaN     NaN
# 40001       2022.0  ...       NaN         NaN          NaN       NaN     NaN
# 9807        2022.0  ...       NaN         NaN          NaN       NaN     NaN
# 40003       2022.0  ...       NaN         NaN          NaN       NaN     NaN
# 159668      2022.0  ...       NaN         NaN          NaN       NaN     NaN
#
#          HOMICIDE_TYPE F_num_removed OCC_TIME_RANGE  DEATH  INJURIES
# OBJECTID
# 7             Stabbing           NaN            NaN    NaN       NaN
# 55            Stabbing           NaN            NaN    NaN       NaN
# 108           Shooting           NaN            NaN    NaN       NaN
# 124           Shooting           NaN            NaN    NaN       NaN
# 125           Shooting           NaN            NaN    NaN       NaN
# ...                ...           ...            ...    ...       ...
# 40006              NaN           NaN            NaN    NaN       NaN
# 40001              NaN           NaN            NaN    NaN       NaN
# 9807               NaN           NaN            NaN    NaN       NaN
# 40003              NaN           NaN            NaN    NaN       NaN
# 159668             NaN           NaN            NaN    NaN       NaN
#
# [26417 rows x 41 columns]
